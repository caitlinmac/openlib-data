# %% [markdown]
# ## 1.2  Retrieve a Specific Dataset:
# Using any of the other API’s available in the above link, construct a dataset using a query that you have put together and fetched data for via the API. Use the examples listed as guidance on how to construct these queries

# %%
import requests
import pandas as pd

# %% [markdown]
# ### Return first page of API query call

# %%
""" 
API CALL: Return 1st page
"""
"https://openlibrary.org/search.json?q=first_publish_year:2019&fields=first_publish_year,title,author_name,language,number_of_pages_median,publisher,format,subject,ratings_average,ratings_sortable,ratings_count,readinglog_count"

# endpoint URL for Open Library search API
url = "https://openlibrary.org/search.json"

# Query parameters
q_params = {
    'q': 'first_publish_year:2019 AND (NOT publisher:Independently Published)',
    'sort': 'random',
    'fields': 'first_publish_year,title,author_name,language,number_of_pages_median,publisher,format,subject,ratings_average,ratings_sortable,ratings_count,readinglog_count',
    'page': 1,  # Start with the first page
    'limit': 100000  # Number of results per page
}

# %%
# %%time
api_data = requests.get(url, params=q_params).json()
# Out:
# CPU times: user 483 ms, sys: 207 ms, total: 689 ms
# Wall time: 2min 14s

# %%
len(api_data['docs'])
# Out:
# 74105

# %% [markdown]
# ### Return ALL pages of API search results using pagination

# %%
"""
# Function to fetch data from the API
def fetch_data(params):
    response = requests.get(url, params=q_params)
    if response.status_code == 200:
        return response.json()
    else:
        print("Error with the request, status code:", response.status_code)
        return None

# Fetch initial data to get the total number of results
initial_data = fetch_data(q_params)
if initial_data:
    total_results = initial_data['numFound']
    print(f"Total Results Found: {total_results}")

    # Initialize a list to store all documents
    all_docs = initial_data['docs']

    # Calculate the total number of pages
    total_pages = (total_results // query_params['limit']) + 1

    # Fetch remaining pages
    for page in range(2, total_pages + 1):
        q_params['page'] = page
        page_data = fetch_data(q_params)
        if page_data:
            all_docs.extend(page_data['docs'])
            print(f"Fetched page {page}/{total_pages}")

    print(f"Total Documents Retrieved: {len(all_docs)}")

    # Now you have all documents in all_docs
    # You can process them as needed
else:
    print("Failed to fetch initial data")
"""

# %% [markdown]
# ### Parse Result into Data set

# %%
df_2019 = pd.DataFrame.from_records(api_data['docs'])
df_2019.head()
# Out:
#                                          author_name  first_publish_year  \
# 0                                    [Michael Grant]                2019
# 1                                       [Kenny Abdo]                2019
# 2            [Patricia L.H. Black, Deborah Hayhusrt]                2019
# 3                                 [Douglas Binstead]                2019
# 4  [David B. Audretsch, Erik E. Lehmann, Albert N...                2019
#
#         format  number_of_pages_median  \
# 0     [mp3 cd]                     1.0
# 1          NaN                     NaN
# 2  [hardcover]                    22.0
# 3          NaN                     NaN
# 4          NaN                   232.0
#
#                                            publisher  \
# 0  [Harpercollins, HarperCollins B and Blackstone...
# 1                          [ABDO Publishing Company]
# 2                          [Monday Creek Publishing]
# 3                       [Upfront Publishing Limited]
# ...

# %%
df_2019.dtypes
# Out:
# author_name                object
# first_publish_year          int64
# format                     object
# number_of_pages_median    float64
# publisher                  object
# title                      object
# language                   object
# readinglog_count          float64
# subject                    object
# ratings_average           float64
# ratings_sortable          float64
# ratings_count             float64
# dtype: object

# %%
# Overview of numeric columns
df_num = df_2019[['first_publish_year', 'number_of_pages_median', 'readinglog_count', 'ratings_average', 'ratings_sortable', 'ratings_count']]
# Overview of categorical (text) columns
df_cat = df_2019[['author_name', 'format', 'publisher', 'title', 'language', 'subject']]

# %%
len(df_2019)
# Out:
# 74105

# %%
#create new column that is a combo of author_name+title
df_2019[['title', 'author_name']].duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 df_2019[['title', 'author_name']].duplicated().sum()
#
# File ~/.pyenv/versions/3.10.6/envs/openlib-env2/lib/python3.10/site-packages/pandas/core/frame.py:6958, in DataFrame.duplicated(self, subset, keep)
#    6956 else:
#    6957     vals = (col.values for name, col in self.items() if name in subset)
# -> 6958     labels, shape = map(list, zip(*map(f, vals)))
#    6960     ids = get_group_index(labels, tuple(shape), sort=False, xnull=False)
#    6961     result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File ~/.pyenv/versions/3.10.6/envs/openlib-env2/lib/python3.10/site-packages/pandas/core/frame.py:6926, in DataFrame.duplicated.<locals>.f(vals)
#    6925 def f(vals) -> tuple[np.ndarray, int]:
# -> 6926     labels, shape = algorithms.factorize(vals, size_hint=len(self))
# ...

# %%
df_2019.isnull().sum().sort_values(ascending=False) / len(df_2019)
# Out:
# ratings_average           0.984765
# ratings_sortable          0.984765
# ratings_count             0.984765
# format                    0.760016
# readinglog_count          0.753863
# subject                   0.566547
# number_of_pages_median    0.471642
# language                  0.162540
# author_name               0.011025
# publisher                 0.000040
# first_publish_year        0.000000
# title                     0.000000
# dtype: float64

# %%
import matplotlib.pyplot as plt

plt.scatter(df_num['readinglog_count'], df_num['ratings_average'])

# %%
plt.hist(df_2019['ratings_sortable'])
# Out:
# (array([ 20.,  43., 176., 677.,  83.,  60.,  39.,  15.,  11.,   5.]),
#  array([1.5545194 , 1.80567223, 2.05682506, 2.30797789, 2.55913072,
#         2.81028355, 3.06143638, 3.31258921, 3.56374204, 3.81489487,
#         4.0660477 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_2019['readinglog_count'])
# Out:
# (array([1.8233e+04, 5.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([   0. ,  404.5,  809. , 1213.5, 1618. , 2022.5, 2427. , 2831.5,
#         3236. , 3640.5, 4045. ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
rate = round(df_num.corr(),2)
sns.heatmap(rate, cmap = "coolwarm", annot = True);

# %% [markdown]
# Quick breakdown:
# readinglog_count and ratings_count --> r=0.88 makes sense
# ratings_sortable is calc'd from ratings_average and ratings_count so relationships with this one are due to leakage
# **0.12 ratings_average and number of pages could be interesting**
# 0 realtionship between ratings_average and ratings_count is also interesting?

# %%
sns.scatterplot(x='number_of_pages_median', y='ratings_average', data=df_2019);

# %%
sns.regplot(x='number_of_pages_median', y='ratings_average', data=df_2019);

# %%
sns.scatterplot(x='number_of_pages_median', y='ratings_count', data=df_2019);
